# %%
joke = '''小明在睡覺被弟弟吵醒你好嗎？
你在睡覺嗎？'''

# %%
joke[0]
# Out:
# '\xe5'

# %%
joke[1]
# Out:
# '\xb0'

# %%
X=name.replace('j','T')

# %%
name = 'jerry'
'T' + name[1:]
# Out:
# 'Terry'

# %%
letters = 'asdfjkl;zxcvm,.qweruio'
letters[:]
# Out:
# 'asdfjkl;zxcvm,.qweruio'

# %%
letters[20:]
# Out:
# 'io'

# %%
letters[:21 :5]
# Out:
# 'akcqi'

# %%
letters[19::4]
# Out:
# 'u'

# %%
str(98.6)
# Out:
# '98.6'

# %%
todos = 'get gloves, get mask, give cat vitamins, call ambulace'
todos.split(',')
['get gloves','get mask','give cat vitamins','call ambulance']
# Out:
# ['get gloves', 'get mask', 'give cat vitamins', 'call ambulance']

# %%
str = "this2009"

# %%
str.isalnum()
# Out:
# True

# %%
import requests
respone = requests.get("http://www.novelscape.net/wxxs/j/jingyong.ffwz/001.htm")
response.encoding = "big5"
book1 = response.text
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-16-b9c37245da38> in <module>()
#       1 import requests
#       2 respone = requests.get("http://www.novelscape.net/wxxs/j/jingyong.ffwz/001.htm")
# ----> 3 response.encoding = "big5"
#       4 book1 = response.text
#
# NameError: name 'response' is not defined

# %%
import requests
respone = requests.get("http://www.novelscape.net/sort/sort12/1.htm")
response.encoding = "big5"
book1 = response.text
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-17-259d676bfb74> in <module>()
#       1 import requests
#       2 respone = requests.get("http://www.novelscape.net/sort/sort12/1.htm")
# ----> 3 response.encoding = "big5"
#       4 book1 = response.text
#
# NameError: name 'response' is not defined

# %%
import requests
respone = requests.get("http://www.novelscape.net/sort/sort12/1.htm")
response.encoding = "big5"
book1 = response.text
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-18-259d676bfb74> in <module>()
#       1 import requests
#       2 respone = requests.get("http://www.novelscape.net/sort/sort12/1.htm")
# ----> 3 response.encoding = "big5"
#       4 book1 = response.text
#
# NameError: name 'response' is not defined

# %%
improt requests
# Out:
#   File "<ipython-input-19-c652c757a14d>", line 1
#     improt requests
#                   ^
# SyntaxError: invalid syntax

# %%
improt requests
response = requests.get("http://www.novelscape.net/wxxs/j/jinyong/ffwz/001.htm")
response.encoding = "big5"
book1 = response.test
# Out:
#   File "<ipython-input-20-7440e6e8b698>", line 1
#     improt requests
#                   ^
# SyntaxError: invalid syntax

# %%
import requests
response = requests.get("http://www.novelscape.net/wxxs/j/jingyong/ffwz/001.htm")
response.encoding = "big5"
book1 = response.text

# %%
book1
# Out:
# u'<HTML><HEAD><meta http-equiv="Content-Type" content="text/html; charset=big5"><TITLE>\u91d1\u5eb8-->\u98db\u72d0\u5916\u50b3-->\u7b2c\u4e00\u7ae0\u3000\u5927\u96e8\u5546\u5bb6\u5821</TITLE>\r\n<META NAME="keywords" CONTENT="\u91d1\u5eb8 \u98db\u72d0\u5916\u50b3 \u7b2c\u4e00\u7ae0\u3000\u5927\u96e8\u5546\u5bb6\u5821">\r\n<META NAME="description" CONTENT="\u91d1\u5eb8 - \u98db\u72d0\u5916\u50b3 - \u7b2c\u4e00\u7ae0\u3000\u5927\u96e8\u5546\u5bb6\u5821">\r\n\r\n<style>\r\n<!--\r\n#page {position:absolute; z-index:0; left:0px; top:0px}\r\n.tt3 {font: 9pt/12pt "\u5b8b\u4f53"}\r\n.tt2 {font: 12pt/15pt "\u5b8b\u4f53"}\r\na {text-decoration:none}\r\na:hover {color: blue;text-decoration:underline}\r\n-->\r\n</style>\r\n</HEAD>\r\n<body text="#000000" link="#0000EE" vlink="#0000EE" alink="#FF0000" bgcolor="#F1F1F3" leftmargin="3" topmargin="3" marginheight="3" marginwidth="3">\r\n<center><table WIDTH="720" >\r\n<tr ALIGN=CENTER>\r\n<td WIDTH="100%">\r\n<center><table BORDER=0 CELLSPACING=0 CE
# ...

# %%
book1[0:50]
# Out:
# u'<HTML><HEAD><meta http-equiv="Content-Type" conten'
